# %% [markdown]
# # Restart-safe modWorm reaudit and perturbation transfer
# Run the cell below. If Colab disconnects, reconnect and run the same cell again. Completed work is discovered from Google Drive and skipped.

# %%
from google.colab import drive
drive.mount('/content/drive')

from pathlib import Path
import shutil, subprocess, sys

REPO = Path('/content/modworm-cloud-surrogate')
BRANCH = 'agent/colab-resume-pipeline'
if REPO.exists():
    shutil.rmtree(REPO)
subprocess.run([
    'git', 'clone', '--depth', '1', '--branch', BRANCH,
    'https://github.com/Kanishka-Reddy/modworm-cloud-surrogate.git',
    str(REPO),
], check=True)
subprocess.run([
    sys.executable, '-m', 'pip', 'install', '-q',
    '-r', str(REPO / 'requirements_colab.txt'),
], check=True)
subprocess.run([
    sys.executable, str(REPO / 'scripts' / 'resume_colab.py'),
    '--drive-root', '/content/drive/MyDrive',
], cwd=REPO, check=True)
